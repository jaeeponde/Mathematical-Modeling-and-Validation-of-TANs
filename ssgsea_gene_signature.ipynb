# %%
gene_sets1="/Users/jaeeponde/Documents/iisc training/ssgsea/HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION.v2023.2.Hs.gmt"
data="/Users/jaeeponde/Documents/iisc training/TGCA/TCGA.LUAD.sampleMap_HiSeqV2"
gene_sets2="//Users/jaeeponde/Documents/iisc training/MARTINELLI_IMMATURE_NEUTROPHIL_DN.v2023.2.Hs.gmt"

# %%
import gseapy as gp
# txt, gct file input
ss1 = gp.ssgsea( data=data,
gene_sets = gene_sets1,
outdir=None,
sample_norm_method='rank',
max_size=300,
min_size=20,
no_plot=True)

# %%
ss2 = gp.ssgsea( data=data,
gene_sets = gene_sets2,
outdir=None,
max_size=15,
min_size=6,
sample_norm_method='rank',
no_plot=True)

# %%
ss1.res2d
# Out:
#                 Name                                        Term           ES  \
# 0    TCGA-44-6774-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  7748.632346
# 1    TCGA-38-4627-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  7738.301704
# 2    TCGA-50-8459-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  7680.758747
# 3    TCGA-75-7030-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  7526.218422
# 4    TCGA-MP-A4TK-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  7336.640141
# ..               ...                                         ...          ...
# 571  TCGA-78-7156-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  3385.482439
# 572  TCGA-86-7955-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  3305.186274
# 573  TCGA-49-4486-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  2784.456221
# 574  TCGA-78-7163-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  2752.008702
# 575  TCGA-55-6972-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  1912.558543
#
#           NES
# 0    1.327713
# ...

# %%
ss2.res2d
# Out:
#                 Name                               Term           ES       NES
# 0    TCGA-44-2662-11  MARTINELLI_IMMATURE_NEUTROPHIL_DN  7045.057358   0.89778
# 1    TCGA-44-6778-11  MARTINELLI_IMMATURE_NEUTROPHIL_DN   6924.89124  0.882467
# 2    TCGA-50-5933-11  MARTINELLI_IMMATURE_NEUTROPHIL_DN  6816.090978  0.868602
# 3    TCGA-44-6147-11  MARTINELLI_IMMATURE_NEUTROPHIL_DN   6622.98763  0.843994
# 4    TCGA-44-2668-11  MARTINELLI_IMMATURE_NEUTROPHIL_DN  6328.048855  0.806409
# ..               ...                                ...          ...       ...
# 571  TCGA-50-5931-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN  -100.871499 -0.012854
# 572  TCGA-MP-A5C7-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN    87.504921  0.011151
# 573  TCGA-NJ-A55R-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN   -84.930928 -0.010823
# 574  TCGA-44-5644-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN    -48.07029 -0.006126
# 575  TCGA-86-A4D0-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN     0.304973  0.000039
#
# [576 rows x 4 columns]

# %%
import pandas as pd
df1 = pd.DataFrame(ss1.res2d)
df2 = pd.DataFrame(ss2.res2d)

# %%
df1 = df1.sort_values(by='Name')
df1
# Out:
#                 Name                                        Term           ES  \
# 425  TCGA-05-4244-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  4963.537183
# 451  TCGA-05-4249-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  4836.068424
# 116  TCGA-05-4250-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  6199.488006
# 35   TCGA-05-4382-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  6739.815238
# 468  TCGA-05-4384-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  4744.915582
# ..               ...                                         ...          ...
# 452  TCGA-NJ-A55O-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  4835.590659
# 264  TCGA-NJ-A55R-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION   5549.12783
# 558  TCGA-NJ-A7XG-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  3733.075893
# 443  TCGA-O1-A52J-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  4871.452791
# 107  TCGA-S2-AA1A-01  HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION  6251.135022
#
#           NES
# 425  0.850493
# ...

# %%
df2 = df2.sort_values(by='Name')
df2
# Out:
#                 Name                               Term           ES       NES
# 155  TCGA-05-4244-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN  3784.951415  0.482332
# 241  TCGA-05-4249-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN  3221.160988  0.410485
# 199  TCGA-05-4250-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN  3442.062681  0.438636
# 93   TCGA-05-4382-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN  4305.203337  0.548629
# 219  TCGA-05-4384-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN  3292.531091   0.41958
# ..               ...                                ...          ...       ...
# 267  TCGA-NJ-A55O-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN  3069.697146  0.391184
# 573  TCGA-NJ-A55R-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN   -84.930928 -0.010823
# 433  TCGA-NJ-A7XG-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN  2108.555216  0.268702
# 153  TCGA-O1-A52J-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN  3810.931206  0.485642
# 463  TCGA-S2-AA1A-01  MARTINELLI_IMMATURE_NEUTROPHIL_DN  1869.076692  0.238184
#
# [576 rows x 4 columns]

# %%
df1.columns
# Out:
# Index(['Name', 'Term', 'ES', 'NES'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have your dataframes df1 and df2

# Extract the 'NES' columns from both dataframes

nes_df1 = df1[df1['Term'] == "HALLMARK_EPITHELIAL_MESENCHYMAL_TRANSITION"]['NES']
nes_df2 = df2[df2['Term'] == "MARTINELLI_IMMATURE_NEUTROPHIL_DN"]['NES']

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(nes_df1, nes_df2, alpha=0.5)
plt.title('Scatter Plot of NES between df1 and df2')
plt.xlabel('EMT')
plt.ylabel('IMMATURE NEUTROPHILS')
plt.grid(True)
plt.show()

# %%
from scipy.stats import pearsonr

# %%
correlation_coefficient, p_value = pearsonr(df1['NES'], df2['NES'])

print(f"Pearson correlation coefficient between '{'NES Neutrophils'}' and '{'NES EMT'}': {correlation_coefficient}")
print(f"P-value: {p_value}")
# Out:
# Pearson correlation coefficient between 'NES Neutrophils' and 'NES EMT': 0.3525931806480548
# P-value: 2.6468172905333632e-18
